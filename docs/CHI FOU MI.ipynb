# %%
from random import *

pointJoueur = 0
choixJoueur = 0

pointOrdi = 0
choixOrdi = 0

for i in range (1, 6):
    choixOrdi = randint(1, 3)              
    
    choixJoueur = input("Choisissez entre Pierre, Feuille et Ciseaux")       
   
        
    if choixJoueur == "Pierre" :
        if choixOrdi == 1:
            print("Egalité")
            
        elif choixOrdi == 2 :
            print("L'ordi a gagné")
            pointOrdi =+ 1
            
        else :
            print("Vous avez gagné !")
            print("Bravo !")
            pointJoueur =+ 1
        
            
    if choixJoueur == "Feuille" :
        if choixOrdi == 1 :
            print("Vous avez gagné !")
            print("Bravo !")
            pointJoueur =+ 1
            
        elif choixOrdi == 2 :
              print("Egalité")
                
        else :
            print("L'ordi a gagné")
            pointOrdi =+ 1
        
            
    if choixJoueur == "Ciseaux" :
        if choixOrdi == 1 :
            print("L'ordi a gagné")
            pointOrdi =+ 1
            
        elif choixOrdi == 2 :
            print("Vous avez gagné !")
            print("Bravo !")
            pointJoueur =+ 1
            
        else :
            print("Egalité")
        

if pointJoueur > pointOrdi :
    print("Vous avez gagné !")
    print("Vous avez", pointJoueur, "points, et l'ordi as", pointOrdi, "points !")
    
elif pointJoueur < pointOrdi :
    print("Dommage, vous avez perdu")
    print("L'ordi avait", pointOrdi, "points, et vous avez", pointJoueur, "points !")
    
elif pointJoueur == pointOrdi :
    print("Egalité !")
    print("Vous aviez", pointJoueur, "points vous et l'ordinateur")
# Out:
# Choisissez entre Pierre, Feuille et CiseauxPierre
# Vous avez gagné !
# Bravo !
# Choisissez entre Pierre, Feuille et CiseauxFeuille
# Egalité
# Choisissez entre Pierre, Feuille et CiseauxCiseaux
# Vous avez gagné !
# Bravo !
# Choisissez entre Pierre, Feuille et CiseauxPierre
# Vous avez gagné !
# Bravo !
# Choisissez entre Pierre, Feuille et CiseauxPierre
# L'ordi a gagné
# Egalité !
# Vous aviez 1 points vous et l'ordinateur

# %%
from random import *

pointJoueur = 0
choixJoueur = 0

pointOrdi = 0
choixOrdi = 0

for i in range (1, 6):
    choixOrdi = randint(1, 3)              
    
    choixJoueur = input("Choisissez entre Pierre, Feuille et Ciseaux")       
   
        
    if choixJoueur == "Pierre" :
        if choixOrdi == 1:
            print("Egalité")
            
        elif choixOrdi == 2 :
            print("L'ordi a gagné")
            pointOrdi = pointOrdi + 1
            
        else :
            print("Vous avez gagné !")
            print("Bravo !")
            pointJoueur = pointJoueur + 1
        
            
    if choixJoueur == "Feuille" :
        if choixOrdi == 1 :
            print("Vous avez gagné !")
            print("Bravo !")
            pointJoueur = pointJoueur + 1
            
        elif choixOrdi == 2 :
              print("Egalité")
                
        else :
            print("L'ordi a gagné")
            pointOrdi = pointOrdi + 1
        
            
    if choixJoueur == "Ciseaux" :
        if choixOrdi == 1 :
            print("L'ordi a gagné")
            pointOrdi = pointOrdi + 1
            
        elif choixOrdi == 2 :
            print("Vous avez gagné !")
            print("Bravo !")
            pointJoueur = pointJoueur + 1
            
        else :
            print("Egalité")
        

if pointJoueur > pointOrdi :
    print("Vous avez gagné !")
    print("Vous avez", pointJoueur, "points, et l'ordi as", pointOrdi, "points !")
    
elif pointJoueur < pointOrdi :
    print("Dommage, vous avez perdu")
    print("L'ordi avait", pointOrdi, "points, et vous avez", pointJoueur, "points !")
    
else:
    print("Egalité !")
    print("Vous aviez", pointJoueur, "points vous et l'ordinateur")
# Out:
# Choisissez entre Pierre, Feuille et CiseauxPierre
# Egalité
# Choisissez entre Pierre, Feuille et CiseauxPierre
# Vous avez gagné !
# Bravo !
# Choisissez entre Pierre, Feuille et CiseauxPierre
# Egalité
# Choisissez entre Pierre, Feuille et CiseauxPierre
# Egalité
# Choisissez entre Pierre, Feuille et CiseauxPierre
# L'ordi a gagné
# Egalité !
# Vous aviez 1 points vous et l'ordinateur
